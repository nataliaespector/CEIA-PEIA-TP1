# %%
# Se importan las librerías necesarias para este ejercicio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importar el archivo de Excel
df_ventas = pd.read_excel('Datos_primer_TP_20Co2025_a2006.xlsx')
df_ventas
# Out:
#           Fecha        Ventas
# 0    2021-01-01  15294.317738
# 1    2021-01-02  15868.651269
# 2    2021-01-03  17208.274959
# 3    2021-01-04  16827.968832
# 4    2021-01-05  18969.807832
# ...         ...           ...
# 1090 2023-12-27  24715.036444
# 1091 2023-12-28  23598.928836
# 1092 2023-12-29  20187.032304
# 1093 2023-12-30  21637.985279
# 1094 2023-12-31  18790.792846
#
# [1095 rows x 2 columns]

# %%
# Se observa el tipo de datos de cada columna y que no hay valores nulos
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fecha   1095 non-null   datetime64[ns]
#  1   Ventas  1095 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 17.2 KB

# %%
# Se observan algunos valores importantes como cantidad de datos, promedio, desviación estándar, 
# mínimo y máximo de cada columna
df_ventas.describe()
# Out:
#                      Fecha        Ventas
# count                 1095   1095.000000
# mean   2022-07-02 00:00:00  20825.555666
# min    2021-01-01 00:00:00  10089.515828
# 25%    2021-10-01 12:00:00  18864.082648
# 50%    2022-07-02 00:00:00  20993.785281
# 75%    2023-04-01 12:00:00  22928.647732
# max    2023-12-31 00:00:00  28811.972591
# std                    NaN   2994.728379

# %%
# Gráfico de todos los datos completos de Ventas en función de Fecha
x_values = df_ventas['Fecha']
y_values = df_ventas['Ventas']

# Graficar
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values)

# Etiquetas y título
plt.xlabel('Fecha')
plt.ylabel('Ventas')
plt.title('Gráfico de Ventas en función de Fecha')
plt.grid()

# Mostrar gráfico
plt.show()

# %%
# Separo los datos en 3 Dataframe según el año
df_ventas_2021=df_ventas[df_ventas['Fecha'].dt.year==2021]
df_ventas_2021
# Out:
#          Fecha        Ventas
# 0   2021-01-01  15294.317738
# 1   2021-01-02  15868.651269
# 2   2021-01-03  17208.274959
# 3   2021-01-04  16827.968832
# 4   2021-01-05  18969.807832
# ..         ...           ...
# 360 2021-12-27  22193.117954
# 361 2021-12-28  23805.565744
# 362 2021-12-29  23611.353649
# 363 2021-12-30  19993.294545
# 364 2021-12-31  18447.993532
#
# [365 rows x 2 columns]

# %%
df_ventas_2022=df_ventas[df_ventas['Fecha'].dt.year==2022]
df_ventas_2022
# Out:
#          Fecha        Ventas
# 365 2022-01-01  11626.761940
# 366 2022-01-02  15622.859998
# 367 2022-01-03  17412.760986
# 368 2022-01-04  15900.250974
# 369 2022-01-05  19498.767501
# ..         ...           ...
# 725 2022-12-27  23105.487248
# 726 2022-12-28  18977.115136
# 727 2022-12-29  17096.353350
# 728 2022-12-30  21862.836770
# 729 2022-12-31  14825.807791
#
# [365 rows x 2 columns]

# %%
df_ventas_2023=df_ventas[df_ventas['Fecha'].dt.year==2023]
df_ventas_2023
# Out:
#           Fecha        Ventas
# 730  2023-01-01  13520.671883
# 731  2023-01-02  16651.717654
# 732  2023-01-03  19383.401083
# 733  2023-01-04  24706.179458
# 734  2023-01-05  18495.949662
# ...         ...           ...
# 1090 2023-12-27  24715.036444
# 1091 2023-12-28  23598.928836
# 1092 2023-12-29  20187.032304
# 1093 2023-12-30  21637.985279
# 1094 2023-12-31  18790.792846
#
# [365 rows x 2 columns]

# %%
# Obtengo la función empírica de distribución (ECDF) para cada año
sns.ecdfplot(df_ventas_2021['Ventas'], label='2021', color='blue')  
sns.ecdfplot(df_ventas_2022['Ventas'], label='2022', color='red')
sns.ecdfplot(df_ventas_2023['Ventas'], label='2023', color='green')
plt.title('Función empírica de distribución (ECDF) por año')
plt.legend()
plt.grid()

# %%
# Obtengo una aproximación a la función de densidad de las ventas (KDE) para cada año
sns.kdeplot(df_ventas_2021['Ventas'], color='blue', label='2021')
sns.kdeplot(df_ventas_2022['Ventas'], color='red', label='2022')      
sns.kdeplot(df_ventas_2023['Ventas'], color='green', label='2023')
plt.title('Función de densidad de ventas (KDE) por año')
plt.legend()
plt.grid()
